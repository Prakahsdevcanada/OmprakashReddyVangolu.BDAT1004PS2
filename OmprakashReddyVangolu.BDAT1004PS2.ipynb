# %% [markdown]
# ## Question 1
#
# ```pyhton
#    Consider the following Python module:
#    a = 0
#    def b():
#     global a
#     a = c(a)
#    def c(a):
#     return a + 2
#    After importing the module into the interpreter, you execute:
#    >>> b()
#    >>> b()
#    >>> b()
#    >>> a
#    ?
#    What value is displayed when the last expression (a) is evaluated? Explain your
#    answer by indicating what happens in every executed statement.
#  ```

# %%
a = 0
def b():
 global a
 a = c(a)
def c(a):
 return a + 2

# %%
b()
b()
b()

# %%
a
# Out:
# 6

# %% [markdown]
# ```python
#
# Variable 'a' was created and two other functions b(),c() are created respectively and
# Variable 'a' used in the funciton d() as a global variable and c() is called from the b().
# As provided, I executed the b() for three times, everytime we execute the b() that inturn
# triggers the c() and this process is repeated for 3 times.
# and everytime c() was executed it return the value so we can use it to replace the old value of
# global vairable 'a'.
# and finally the answer a = 6
#
# ```

# %% [markdown]
# # Question 2
#
# ```python
#
# Function fileLength(), given to you, takes the name of a file as input and returns
# the length of the file:
# >>> fileLength('midterm.py')
# 284
# >>> fileLength('idterm.py')
# Traceback (most recent call last):
# File "<pyshell#34>", line 1, in <module>
#  fileLength('idterm.py')
# File "/Users/me/midterm.py", line 3, in fileLength
#  infile = open(filename)
# FileNotFoundError: [Errno 2] No such file or directory:
# 'idterm.py'
# As shown above, if the file cannot be found by the interpreter or if it cannot be read
# as a text file, an exception will be raised. Modify function fileLength() so that a
# friendly message is printed instead:
# >>> fileLength('midterm.py')
# 358
# >>> fileLength('idterm.py')
# File idterm.py not found.
#
# ```

# %%
def fileLength(H):
    try:
        info = open ('Hello.py')
        info2 = read(info)
        print(info2)
    except:
        print('File Hello.py not found')

Hello = "hello.py"
fileLength(Hello)


def file_length(file_name):
    file = open(file_name)
    contents = file.read()
    file.close()
    print(len(contents))
# Out:
# File Hello.py not found

# %% [markdown]
# # Question 3
# ```python
# Write a class named Marsupial that can be used as shown below:
# >>> m = Marsupial()
# >>> m.put_in_pouch('doll')
# >>> m.put_in_pouch('firetruck')
# >>> m.put_in_pouch('kitten')
# >>> m.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the
# attributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, the
# coordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input and
# moves the kangaroo by dx units along the x-axis and by dy units along the yaxis, and
# c. overloads the __str__ operator so it behaves as shown below.
# >>> k = Kangaroo(0,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (0,0)
# >>> k.put_in_pouch('doll')
# >>> k.put_in_pouch('firetruck')
# >>> k.put_in_pouch('kitten')
# >>> k.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (3,0)
# ```

# %%
class Marsupial():
    def __init__(self, name = [], x = 0 , y = 0):
        self.x = name
        self.c = x
        self.d = y
    def put_in_pouch(self, nam):
        self.x = self.x + [nam]
    def pouch_contents(self):
        print(self.x)

    
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
m.pouch_contents()



class Kangaroo(Marsupial):
    def __init__(self, coorx = 0, coory = 0):
        super().__init__()
        self.a = coorx
        self.b = coory
    def jump(self, dx, dy):
        self.a = self.a + dx
        self.b = self.b + dy
    def __repr__(self):
        return "I am a Kangaroo located at ({},{})".format(self.a,self.b)
k = Kangaroo(0,0)
print(k)

#print(help(Kangaroo))


#k = Kangaroo(m)
Marsupial.put_in_pouch(k, 'doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()

k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at (0,0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at (3,0)

# %% [markdown]
# # Question 4
# ```python
# Write function collatz() that takes a positive integer x as input and prints the
# Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying
# this rule to the previous number x in the sequence:
# x = {
# 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
# 3𝑥 + 1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
# Your function should stop when the sequence gets to number 1. Your
# implementation must be recursive, without any loops.
# >>> collatz(1)
# 1
# >>> collatz(10)
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# ```

# %%
# function takes a positive integer
# create a recursive funtion for the same

def even(n):
    print(n)
    q = n//2
    n = q
    collatz(n)
    
def odd(n):
    print(n)
    n = 3*n + 1
    collatz(n)

    
def collatz(n):
    #n = int(input("Enter a positive integer: "))
    if n%2 == 0:
        even(n)
    elif n == 1:
        print(1)
    else:
        odd(n)
    

collatz(10)
# Out:
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# # Question 5
# ```python
# Write a recursive method binary() that takes a non-negative
# integer n and prints the binary representation of integer n.
# >>> binary(0)
# 0
# >>> binary(1)
# 1
# >>> binary(3)
# 11
# >>> binary(9)
# 1001
# ```

# %%
binary_str = ""
binary_value = ""
def binary(n):
    #n = int(input("Enter an positive integer: ")  
    global binary_str
    global binary_value
    if n == 1:
        binary_str = str(n) + binary_str
        print(binary_str)
        binary_str = ""
    elif n == 0:
        binary_str = str(n) + binary_str 
        print(binary_str)
        binary_str = ""
    else:
        binary_str = str(n%2) + binary_str
        n = n//2
        binary(n)
        print (binary_str, end ='')
    binary_str = ""
binary(0)
binary(1)
binary(3)
binary(9)
binary(24)
binary(32)
# Out:
# 0
# 1
# 11
# 1001
# 11000
# 100000

# %% [markdown]
# # Question 6
#
# ```python
# Implement a class named HeadingParser that can be used to parse an HTML
# document, and retrieve and print all the headings in the document. You should
# implement your class as a subclass of HTMLParser, defined in Standard Library
# module html.parser. When fed a string containing HTML code, your class should
# print the headings, one per line and in the order in which they appear in the
# document. Each heading should be indented as follows: an h1 heading should have indentation 0, and h2 heading should have indentation 1, etc. Test your
# implementation using w3c.html.
# >>> infile = open('w3c.html')
# >>> content = infile.read()
# >>> infile.close()
# >>> hp = HeadingParser()
# >>> hp.feed(content)
# W3C Mission
# Principles
# ```

# %%
from urllib.request import urlopen

infile = open('w3c.html')
content = infile.read()
#print(content)
#print(type(content))
infile.close()
class HeadingParser:
    def __init__(slef):
        pass
    def feed(self, content):
        #self.content = content
        a = content.splitlines()
        #print(a)
        for i in a:
            if i.__contains__("h1"):
                b = i.split(">")[1].split("<")[0]
                print(b)
                #print(i)
            elif i.__contains__("h2"):
                b = i.split(">")[1].split("<")[0]
                print(" "+b)
                #print(" " + i)
            else:
                pass
        
        
    
hp = HeadingParser()
hp.feed(content)
# Out:
# W3C Mission
#  Principles

# %% [markdown]
# # Question 7
# ```python
# Implement recursive function webdir() that takes as input: a URL (as a string) and
# non-negative integers depth and indent. Your function should visit every web
# page reachable from the starting URL web page in depth clicks or less, and print
# each web page's URL. As shown below, indentation, specified by indent, should
# be used to indicate the depth of a URL.
# >>>
# webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html'
# , 2, 0)
# http://reed.cs.depaul.edu/lperkovic/csc242/test1.html
#  http://reed.cs.depaul.edu/lperkovic/csc242/test2.html
#  http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
#  http://reed.cs.depaul.edu/lperkovic/csc242/test3.html
#  http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
#
# ```

# %%
from urllib.parse import urljoin
from html.parser import HTMLParser
class Collector(HTMLParser):
    'collects hyperlink URLs into a list'

    def __init__(self, url):
        'initializes parser, the url, and a list'
        HTMLParser.__init__(self)
        self.url = url
        self.links = []

    
    def handle_starttag(self, tag, attrs):
        'collects hyperlink URLs in their absolute format'
        if tag == 'a':
            for attr in attrs:
                if attr[0] == 'href':
                    # construct absolute URL
                    absolute = urljoin(self.url, attr[1])
                    if absolute[:4] == 'http': # collect HTTP URLs
                        self.links.append(absolute)
                        
    def getLinks(self):
        'returns hyperlinks URLs in their absolute format'
        return self.links



# c = Collector('https://reed.cs.depaul.edu/lperkovic/test1.html')
# c.handle_starttag()
def webdir(string):
    print(string)
    resource = urlopen(string)
    content = resource.read().decode()
    c = Collector(string)
    c.feed(content)
    d = c.getLinks()
    print(d)
    
webdir('https://reed.cs.depaul.edu/lperkovic/test1.html')
# Out:
# https://reed.cs.depaul.edu/lperkovic/test1.html
# ['http://reed.cs.depaul.edu/lperkovic/test2.html', 'https://reed.cs.depaul.edu/lperkovic/test3.html']

# %% [markdown]
# # Question 8
# ```pyhton
# Write SQL queries on the below database table that return:
# a) All the temperature data.
# b) All the cities, but without repetition.
# c) All the records for India.
# d) All the Fall records.e) The city, country, and season for which the average rainfall is between 200
# and 400 millimeters.
# f) The city and country for which the average Fall temperature is above 20
# degrees, in increasing temperature order.
# g) The total annual rainfall for Cairo.
# h) The total rainfall for each season.
# City Country Season Temperature
# (C)
# Rainfall
# (mm)
# Mumbai India Winter 24.8 5.9
# Mumbai India Spring 28.4 16.2
# Mumbai India Summer 27.9 1549.4
# Mumbai India Fall 27.6 346.0
# London United Kingdom Winter 4.2 207.7
# London United Kingdom Spring 8.3 169.6
# London United Kingdom Summer 15.7 157.0
# London United Kingdom Fall 10.4 218.5
# Cairo Egypt Winter 13.6 16.5
# Cairo Egypt Spring 20.7 6.5
# Cairo Egypt Summer 27.7 0.1
# Cairo Egypt Fall 22.2 4.5
#
# ```

# %% [markdown]
# ```python
#
# a) SELECT temperature from table;
#
# b) SELECT unique(city) from talbe;
#
# c) SELECT * from table where country = "India";
#
# d) SELECT * from table where season = "Fall";
#
# e) SELECT city, country, season from table where ranifall > 200 and rainfall < 400;
#
# f) SELECT city, country from table where season = 'Fall' and temperature > 20 ORDER BY temperature DESC;
#
# g) SELECT SUM(rainfall) AS Annual_rainfall from table where city = 'Cairo';
#
# h) SELECT SUM(rainfall) AS total_rainfall, season from table GROUP BY season;
#
# ```

# %% [markdown]
# # Question 9
#
#  ```python
# Suppose list words is defined as follows:
# >>> words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over',
# 'the', 'lazy', 'dog']
# Write list comprehension expressions that use list words and generate the following
# lists:
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE',
# 'LAZY', 'DOG']
# b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog']
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list
# words).
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN',
# 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5],
# ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy',
# 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list
# words, where each list contains the word in uppercase and lowercase and the
# length of the word.)
# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog'] (the list of words in list words containing 4 or more
# characters.)
# ```

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# A.=======================

a = []
for i in words:
    a.append(i.upper()) 
print(a)


# # B.=======================

b = []
for i in words:
    b.append(i.lower()) 
print(b)

# b = []
# for i in range(len(words)):
#     b = words
#     b[i] = b[i].lower()  
# print(b)


# # C.=======================

c = []
for i in words:
    c.append(len(i)) 
print(c)

# c = []
# for i in range(len(words)):
#     c = words
#     c[i] = len(c[i])
# print(c)


# # D.=======================

e = list(zip(a,b,c))
#print(e)
f = []
for i in e:
    f.append(list(i))

print(f)



# E.=======================

words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
h = []
j = []
h = words
for i in range(len(words)):
    if len(h[i]) >= 4:
        j.append(h[i])
        #print(j)
    else:
        pass

print(j)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
